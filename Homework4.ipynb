# %% [markdown]
# Design Optimization Homework 5

# %% [markdown]
# ![DOHW4Q1.png](attachment:DOHW4Q1.png)

# %% [markdown]
# ![](DOHW4D1.png)

# %% [markdown]
# ![DOHW4PR1P1.jpeg](attachment:DOHW4PR1P1.jpeg)

# %% [markdown]
# ![DOHW4PR1P2.jpeg](attachment:DOHW4PR1P2.jpeg)

# %% [markdown]
# ![DOHW4PR1P3.jpeg](attachment:DOHW4PR1P3.jpeg)

# %% [markdown]
# ![DOHW4Q2.png](attachment:DOHW4Q2.png)

# %% [markdown]
# ![DOHW4PR2P1.jpeg](attachment:DOHW4PR2P1.jpeg)

# %% [markdown]
# ![DOHW4PR2P2.jpeg](attachment:DOHW4PR2P2.jpeg)

# %% [markdown]
# ![DOHW4Q3.png](attachment:DOHW4Q3.png)

# %% [markdown]
# ![DOHW4PR3P1.jpeg](attachment:DOHW4PR3P1.jpeg)

# %% [markdown]
# ![DOHW4PR3P2.jpeg](attachment:DOHW4PR3P2.jpeg)

# %% [markdown]
# ![DOHW4PR3P3.jpeg](attachment:DOHW4PR3P3.jpeg)

# %% [markdown]
# ![DOHW4Q4.png](attachment:DOHW4Q4.png)

# %% [markdown]
# ![DOHW4PR4P1.jpeg](attachment:DOHW4PR4P1.jpeg)

# %% [markdown]
# ![](DOHW4PR4P2.JPEG)

# %% [markdown]
# ![DOHW4PR4P3.jpeg](attachment:DOHW4PR4P3.jpeg)

# %% [markdown]
# So, When b=4, x1=1 and x2=2, the solution is local minimmum

# %% [markdown]
# ![DOHW4Q5.png](attachment:DOHW4Q5.png)
